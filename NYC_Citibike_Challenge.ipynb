# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
citi_bike_df = pd.read_csv('201908-citibike-tripdata.csv')

# %%
# 2. Check the datatypes of your columns. 
citi_bike_df.sample(10)
# Out:
#          tripduration                 starttime                  stoptime  \
# 1532167          1521  2019-08-20 21:40:01.0270  2019-08-20 22:05:22.7630
# 1164211          1498  2019-08-16 00:04:06.2800  2019-08-16 00:29:04.8750
# 919199           1067  2019-08-12 20:12:22.9340  2019-08-12 20:30:10.0380
# 118863            546  2019-08-02 12:56:23.3190  2019-08-02 13:05:29.7190
# 90240              79  2019-08-02 05:54:03.2840  2019-08-02 05:55:22.8540
# 1919069           682  2019-08-26 12:14:45.3100  2019-08-26 12:26:08.2820
# 481056            582  2019-08-07 05:49:35.3450  2019-08-07 05:59:17.3610
# 1627831           999  2019-08-22 09:28:27.9380  2019-08-22 09:45:07.1970
# 2189666           274  2019-08-29 19:27:18.0370  2019-08-29 19:31:52.7560
# 1830957           190  2019-08-25 10:27:13.7910  2019-08-25 10:30:24.6810
#
#          start station id           start station name  \
# 1532167            3758.0       George St & Wilson Ave
# ...

# %%
# 3. Convert the 'tripduration' column to datetime datatype.

citi_bike_df['tripduration'] = pd.to_datetime(citi_bike_df['tripduration'], unit='s', infer_datetime_format=True)
citi_bike_df.head(1)
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 00:06:33  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
#
#    start station id      start station name  start station latitude  \
# 0             531.0  Forsyth St & Broome St               40.718939
#
#    start station longitude  end station id       end station name  \
# 0               -73.992663           408.0  Market St & Cherry St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.710762             -73.994004   35305  Subscriber
#
#    birth year  gender
# 0        1996       2

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citi_bike_df.to_csv(r'C:\Users\josep\Documents\GitHub\bikesharing\NYC_Citibike_tripduration.csv', index=False)
